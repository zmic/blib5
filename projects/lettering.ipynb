# %%
import bpy

type(bpy.data)
# Out:
# bpy.types.BlendData

# %%
print(type(bpy.data.libraries))
bpy.data.libraries.rna_type
# Out:
# <class 'bpy_prop_collection'>
# <bpy_struct, Struct("BlendDataLibraries") at 0x2acb4f80>

# %%
data_path = "/home/ik/Dev/blib5@github/assets/lettering/dagger-2026-05-07.blend"
with bpy.data.libraries.load(data_path) as (data_src, data_dst):
    
    print(type(data_dst))
# Out:
# <class 'bpy_lib'>

# %%
from blib5.network import blender_connect
C = blender_connect()
