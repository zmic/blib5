# %%
import bpy

print(type(bpy.data))
print(bpy.data.rna_type)

# %%
print(type(bpy.data.libraries))
print(bpy.data.libraries.rna_type)

# %%
data_path = "/home/ik/Dev/blib5@github/assets/lettering/dagger-2026-05-07.blend"
with bpy.data.libraries.load(data_path) as (data_src, data_dst):

    print(data_src.keys())

# %%
import importlib
import sys
n = importlib.import_module('blib5.network')
print(n.__spec__.parent)
globals()['a']=1
print(sys.modules)
m = importlib.import_module('blib5.geo.bezier')
print(m.__spec__.parent)
sys.modules['blib5']

# %%
import importlib
import sys
m = importlib.import_module('blib5.geo.bezier')
print(sys.modules.keys())
sys.modules['blib5'].geo.bezier
# Out:
# dict_keys(['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', '_io', 'marshal', 'posix', '_frozen_importlib_external', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings', 'encodings.utf_8', '_signal', '_abc', 'abc', 'io', '__main__', '_stat', 'stat', '_collections_abc', 'errno', 'genericpath', 'posixpath', 'os.path', 'os', '_sitebuiltins', 'encodings.utf_8_sig', '_virtualenv', 'site', 'importlib._bootstrap', 'importlib._bootstrap_external', 'importlib', 'importlib.machinery', 'importlib._abc', 'types', 'importlib.util', 'runpy', 'collections.abc', 'itertools', 'keyword', '_operator', 'operator', 'reprlib', '_collections', 'collections', '_functools', 'functools', 'contextlib', 'enum', '_sre', 're._constants', 're._parser', 're._casefix', 're._compiler', 'copyreg', 're', 'fnmatch', 'glob', 'pathlib._abc', 'ntpath', 'warnings', 'pwd', 'grp', 'pathlib._local', 'pathlib', 'ipykernel._version', '__future__', '_json', 'json.scanner', 'json.decoder', 'json.encoder', 'json', '_locale', 'locale', 'signal', '_weakrefset', 'threading', 'fcntl', '_posixsubprocess', 'select', 'math', 'selectors', 'subprocess', '_typing', 'typing', 'jupyter_client._version', 'platform', 'zmq.backend.select', 'cython_runtime', '_ast', 'ast', '_opcode', '_opcode_metadata', 'opcode', 'dis', 'linecache', 'token', '_tokenize', 'tokenize', 'weakref', 'inspect', '_cython_3_1_3limited_fastcallnofinalize', 'zmq.constants', 'zmq.error', 'zmq.backend.cython._zmq', 'zmq.backend.cython', 'zmq.backend', 'atexit', 'zmq._typing', 'zmq.utils', 'zmq.utils.interop', 'zmq.sugar.attrsettr', '_struct', 'struct', '_compat_pickle', '_pickle', 'pickle', '_bisect', 'bisect', '_random', 'random', 'zmq.utils.jsonapi', 'zmq.sugar.poll', 'zmq.sugar.socket', 'zmq.sugar.context', 'zmq.sugar.frame', 'zmq.sugar.tracker', 'zmq.sugar.version', 'zmq.sugar.stopwatch', 'zmq.sugar', 'zmq', 'concurrent', 'textwrap', '_colorize', 'traceback', '_string', 'string', 'logging', 'concurrent.futures._base', 'concurrent.futures', '_heapq', 'heapq', '_socket', 'array', 'socket', '_ssl', 'binascii', 'base64', 'ssl', 'asyncio.constants', 'asyncio.coroutines', '_contextvars', 'contextvars', 'asyncio.format_helpers', 'asyncio.base_futures', 'asyncio.exceptions', 'asyncio.base_tasks', '_asyncio', 'asyncio.events', 'asyncio.futures', 'asyncio.protocols', 'asyncio.transports', 'asyncio.log', 'asyncio.sslproto', 'asyncio.mixins', 'asyncio.locks', 'asyncio.queues', 'asyncio.timeouts', 'asyncio.tasks', 'asyncio.staggered', 'asyncio.trsock', 'asyncio.base_events', 'asyncio.runners', 'asyncio.streams', 'asyncio.subprocess', 'asyncio.taskgroups', 'asyncio.threads', 'asyncio.base_subprocess', 'asyncio.selector_events', 'asyncio.unix_events', 'asyncio', 'zmq._future', 'zmq.asyncio', 'numbers', 'traitlets.utils', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.warnings', 'traitlets.traitlets', 'traitlets._version', 'copy', 'traitlets.utils.decorators', 'traitlets', '_queue', 'queue', 'jupyter_core.version', 'jupyter_core', 'jupyter_core.utils', 'jupyter_client.channelsabc', '_hashlib', '_blake2', 'hashlib', 'hmac', 'dataclasses', 'pprint', '_datetime', 'datetime', 'tornado', 'logging.handlers', 'html.entities', 'html', 'urllib', 'ipaddress', 'urllib.parse', 'zlib', 'tornado.speedups', 'tornado.util', 'tornado.escape', '_curses', 'curses', 'tornado.log', 'tornado.concurrent', 'tornado.ioloop', 'socketserver', 'logging.config', 'traitlets.utils.text', 'gettext', 'argparse', 'traitlets.config.loader', 'traitlets.config.configurable', 'traitlets.utils.nested_update', 'traitlets.config.application', 'traitlets.config', 'traitlets.log', 'zmq.eventloop', 'zmq.eventloop.zmqstream', 'jupyter_client.adapter', 'dateutil._version', 'dateutil', 'calendar', 'six', '_decimal', 'decimal', 'dateutil._common', 'dateutil.relativedelta', 'six.moves', 'dateutil.tz._common' ...
# <module 'blib5.geo.bezier' from '/home/ik/Dev/blib5@github/blib5/package/src/blib5/geo/bezier.py'>

# %%
from blib5.remote import connection
remote = connection()

# %%
remote.import_lib('blib5.geo')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 remote.import_lib('blib5.geo')
#
# File ~/Dev/blib5@github/blib5/package/src/blib5/remote.py:149, in connection.import_lib(self, module)
#     147 if isinstance(module, types.ModuleType):
#     148     module = module.__name__
# --> 149 self.command('import_module__', module)
#
# File ~/Dev/blib5@github/blib5/package/src/blib5/remote.py:139, in command(self, command, *args, **kwargs)
#     137 b = dill.dumps((command, args, kwargs))
#     138 send_packet(self.s, b)
# --> 139 data = receive_packet(self.s)
#     140 error, rv = dill.loads(data)
#     141 if error:
#
# File ~/Dev/blib5@github/blib5/package/.venv/lib/python3.13/site-packages/dill/_dill.py:312, in loads(str, ignore, **kwds)
#     301 """
#     302 Unpickle an object from a string.
#     303
#    (...)    309 Default values for keyword arguments can be set in :mod:`dill.settings`.
#     310 """
#     311 file = StringIO(str)
# --> 312 return load(file, ignore, **kwds)
#
# File ~/Dev/blib5@github/blib5/package/.venv/lib/python3.13/site-packages/dill/_dill.py:298, in load(file, ignore, **kwds)
#     292 def load(file, ignore=None, **kwds):
#     293     """
#     294     Unpickle an object from a file.
#     295
#     296     See :func:`loads` for keyword arguments.
#     297     """
# --> 298     return Unpickler(file, ignore=ignore, **kwds).load()
#
# File ~/Dev/blib5@github/blib5/package/.venv/lib/python3.13/site-packages/dill/_dill.py:453, in Unpickler.load(self)
#     452 def load(self): #NOTE: if settings change, need to update attributes
# --> 453     obj = StockUnpickler.load(self)
#     454     if type(obj).__module__ == getattr(_main_module, '__name__', '__main__'):
#     455         if not self._ignore:
#     456             # point obj class to main
#
# EOFError: Ran out of input

# %%
s, t = 'ab', 'cd'
f"{s+t:^10}"
# Out:
# '   abcd   '

# %%
import sys
import importlib
m = importlib.import_module('blib5.module')
base_module = m.__name__.split('.')[0]
base_module
# Out:
# 'blib5'

# %%
sys = importlib.import_module('sys')
sys.argv
blib5 = importlib.import_module('blib5')
blib5.curve = importlib.import_module('blib5.curve')
blib5.curve.__dict__
type(blib5.curve)
import types
isinstance(blib5.curve, types.ModuleType)
# Out:
# True
