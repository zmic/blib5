# %%
import bpy
from blib5.remote import connection

remote = connection()

# %%
remote.import_lib('blib5.mesh')

# %%
import blib5.scene
remote.import_lib('blib5.scene')
collections = [
    'imported',
    'dagger',
    'six'
]
remote.command('blib5.scene.ensure_collections', collections)
blib5.scene.ensure_collections(collections)

# %%
font_path = '/home/ik/data/fonts/AGaramondPro-Regular.otf'
bpy.data.fonts.load(font_path)
remote.command('bpy.data.fonts.load', font_path)
# Out:
# bpy.data.fonts['Adobe Garamond Pro Regular']
